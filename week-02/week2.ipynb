# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziedny28/PCVK-Ganjil-2023/blob/main/week-02/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum

# %%
from google.colab import drive


#Accessing google drive
drive.mount('/content/drive');
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Colab Notebooks/Kampus-PCVK/Datas/Images/kitten01.png')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Colab Notebooks/Kampus-PCVK/Datas/Images/kitten01.png',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap="gray")

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
cv.imwrite('/content/drive/MyDrive/Colab Notebooks/Kampus-PCVK/Datas/Images/mandirill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text="Hello", org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400, 300], [200, 400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Pertanyaan

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
# ```python
# from google.colab.patches import cv2_imshow
# from skimage import io
# ```
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# **Jawaban**
#
# 1.  Jika menggunakan matplotlib akan muncul ukuran dari gambar, jika tidak, tidak akan muncul
#
# 2. Secara visual akan terlihat sama. Namun, secara teknis, ada perbedaan kecil di antara keduanya. Gambar dengan tipe data int16 akan memiliki nilai minimum yang lebih rendah dibandingkan gambar dengan tipe data int32 hal ini membuat jangkauan warna int32 lebih baik
#
# 3. baris kode tersebut adalah proses import fungsi ``` cv2. imshow() ``` dari liblary ```google.colab.patches``` yang  memungkinkan menampilkan gambar yang tersimpan di google drive pada google collab
#
# 4. disana kita mengimport  ``` io ``` dari liblary ```skimage``` yang  memungkinkan menampilkan gambar yang tersimpan di google drive pada google collab

# %% [markdown]
# # Tugas

# %% [markdown]
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
#
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-115, kolom 25-120!
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
# 6. Tampilkan image dengan posisi terbalik!
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.
# 10. Tunjukkan code program anda pada bapak/ibu dosen

# %% [markdown]
# **Jawaban**
#
# 1. figzize akan mengatur ukuran gambar ketika ditampilkan namun tidak akan merubah ukuran pixel
# 2. image dalam channel Red-Blue dan Green-Blue

# %%
img_red_blue = img.copy() #get image
img_red_blue[:, :, 1] = 0

plt.imshow(img_red_blue)

# %%
img_green_blue = img.copy() #get image
img_green_blue[:, :, 0] = 0

plt.imshow(img_green_blue)

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
img_no_3 = img.copy()
img_no_3 = img_no_3[20:115, 25:120]
plt.imshow(img_no_3)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
img_no_4 = img.copy()
img_no_4 = img_no_4[5:30,:]
img_no_4[:,:,1] = img_no_4[:,:,2] = 0
plt.imshow(img_no_4)

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
img_no_6 = cv.rotate(img, cv.ROTATE_180)
img_no_6 = cv.cvtColor(img_no_6, cv.COLOR_BGR2RGB)
plt.imshow(img_no_6)

# %% [markdown]
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
img_me = cv.imread('/content/drive/MyDrive/Colab Notebooks/Kampus-PCVK/Datas/Images/Ik.jpeg')

#vertices = np.array([[450,300], [550,300], [500, 200]],dtype=np.int32)
#pts = vertices.reshape((-1,1,2))
#cv.polylines(img_me, [pts], isClosed=True, color=(255,0,0), thickness=5)

cv.rectangle(img_me,pt1=(400,350),pt2=(600,200),color=(0,0,255),thickness=15)

cv.circle(img_me,center=(500,270),radius=80,color=(255,0,0),thickness=8)

img_me = cv.cvtColor(img_me, cv.COLOR_BGR2RGB)
plt.imshow(img_me)

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
img_kitten_rectangle = img.copy()


rect_width_limit = 100
rect_height_limit = 100
img_kitten_rectangle[-rect_height_limit:, : rect_width_limit, 0] = 255

img_kitten_rectangle = cv.cvtColor(img_kitten_rectangle, cv.COLOR_BGR2RGB)
plt.imshow(img_kitten_rectangle)

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img_kitten_rectangle, text="Ya To", org=(100,350),fontFace=font,fontScale=2,color=(255,255,0),thickness=2, lineType=cv.LINE_AA)

plt.imshow(img_kitten_rectangle)
